# %% [markdown]
# ## Leaflet maps with folium
#
# The folium library is the Python leaflet JS library implementation. In order to create an interactive map you will need to specify the desired coordinates with location and the desired level of zoom with zoom_start.

# %%
import folium

# Interactive map
m = folium.Map(location = [34.06, -118.25], zoom_start = 8)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8435e809709cf9408901681427c91c77 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8435e809709cf9408901681427c91c77&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8435e809709cf9408901681427c91c77 = L.map(
#                 &quot;map_8435e809709cf9408901681427c91c77&quot;,
#                 {
#                     center: [34.06, -118.25],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d2b3baed99bf72be8a76b75cdcd2ee0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d2b3baed99bf72be8a76b75cdcd2ee0.addTo(map_8435e809709cf9408901681427c91c77);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Base maps
# The tiles argument allows specifying different base maps, such as "Stamen Terrain", "CartoDB Positron", "stamentoner", etc. The default value is "OpenStreetMap" and you can find more leaflet providers online.
#
# https://leaflet-extras.github.io/leaflet-providers/preview/
#
# ##🌍 Free & Built-in Basemap Styles
# OpenStreetMap (OSM)
#
# "OpenStreetMap" – default Leaflet map
#
# Variants: Standard, Black & White, HOT (Humanitarian)
#
# Carto
#
# "CartoDB positron" – light, clean style
#
# "CartoDB dark_matter" – dark theme
#
# Stamen
#
# "Stamen Terrain" – shaded relief, terrain style
#
# "Stamen Toner" – black & white high contrast
#
# "Stamen Watercolor" – artistic, watercolor effect
#
# Esri (ArcGIS)
#
# "Esri WorldStreetMap"
#
# "Esri DeLorme"
#
# "Esri WorldTopoMap"
#
# "Esri WorldImagery" (satellite imagery)
#
# "Esri OceanBasemap"
#
# "Esri NatGeoWorldMap"
#
# "Esri WorldGrayCanvas"
#
# NASA / USGS
#
# "NASAGIBS Blue Marble"
#
# "NASAGIBS VIIRS"

# %%
import folium

# Interactive map
m = folium.Map(location = [34.06, -118.25], zoom_start = 9,
               tiles = "CartoDB Positron")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2505e477297e2ac73cd963a7c02fab22 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2505e477297e2ac73cd963a7c02fab22&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2505e477297e2ac73cd963a7c02fab22 = L.map(
#                 &quot;map_2505e477297e2ac73cd963a7c02fab22&quot;,
#                 {
#                     center: [34.06, -118.25],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e61a20935503fb4b919e0d992aa3ae72 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e61a20935503fb4b919e0d992aa3ae72.addTo(map_2505e477297e2ac73cd963a7c02fab22);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Markers
# Markers can be added to folium maps with folium.Marker and add_to functions. After creating you map you will ble able to add the marker, specifying the desired location, as in the example below.

# %%
import folium

m = folium.Map(location = [34.06, -118.25], zoom_start = 8)

# Add a marker to the map
folium.Marker(location = [34.06, -118.25]).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_daea619b3eac738e48d62de0573a04b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_daea619b3eac738e48d62de0573a04b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_daea619b3eac738e48d62de0573a04b1 = L.map(
#                 &quot;map_daea619b3eac738e48d62de0573a04b1&quot;,
#                 {
#                     center: [34.06, -118.25],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a40bfd7d23459c88441ce40f0480107 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a40bfd7d23459c88441ce40f0480107.addTo(map_daea619b3eac738e48d62de0573a04b1);
#
#
#             var marker_decb9f84716ee6a4dd80ade4ed9287b3 = L.marker(
#                 [34.06, -118.25],
#                 {
# }
#             ).addTo(map_daea619b3eac738e48d62de0573a04b1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Markers with icon
#
# The markers can also have a bootstrap icon and a custom color. You will need to pass folium.Icon to the icon argument with the desired icon and color.

# %%
import folium

m = folium.Map(location = [34.06, -118.25], zoom_start = 8)

# Add a marker with icon to the map
folium.Marker(location = [34.06, -118.25],
              icon = folium.Icon(icon = "cloud", color = "red")).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fcf0e57c3abafcf2638b742b2943644 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fcf0e57c3abafcf2638b742b2943644&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fcf0e57c3abafcf2638b742b2943644 = L.map(
#                 &quot;map_1fcf0e57c3abafcf2638b742b2943644&quot;,
#                 {
#                     center: [34.06, -118.25],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a422d1620e641ded2abc505b9f8f2a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a422d1620e641ded2abc505b9f8f2a2.addTo(map_1fcf0e57c3abafcf2638b742b2943644);
#
#
#             var marker_0d69b962001200d4f3ad66896578e54d = L.marker(
#                 [34.06, -118.25],
#                 {
# }
#             ).addTo(map_1fcf0e57c3abafcf2638b742b2943644);
#
#
#             var icon_7ff6b81e1d60eb4bc6b9459c52c9a6c1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_0d69b962001200d4f3ad66896578e54d.setIcon(icon_7ff6b81e1d60eb4bc6b9459c52c9a6c1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Circle markers
#
# Markers can also be circles that can be added with CircleMarker. These markers can be customized in several ways, as it is possible to customize the radius (in pixels), the fill and border color or the opacity.

# %%
import folium

m = folium.Map(location = [34.06, -118.25], zoom_start = 8)

# Add a circle marker
folium.CircleMarker(
    location = [34.06, -118.25],
    radius = 10,
    fill = True,
    color = "blue",
    fill_color = "red",
    fill_opacity = 0.25).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6f40bee80f856de5d1f32bbc24559a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6f40bee80f856de5d1f32bbc24559a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6f40bee80f856de5d1f32bbc24559a7 = L.map(
#                 &quot;map_c6f40bee80f856de5d1f32bbc24559a7&quot;,
#                 {
#                     center: [34.06, -118.25],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de75ca83ad24479456087e27500fc1b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_de75ca83ad24479456087e27500fc1b0.addTo(map_c6f40bee80f856de5d1f32bbc24559a7);
#
#
#             var circle_marker_e6f3eb8e09df3c141f6e82e22c5e49d5 = L.circleMarker(
#                 [34.06, -118.25],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.25, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c6f40bee80f856de5d1f32bbc24559a7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Adding several markers at once
#
# Note that you can add as many markers as you want. If you have a data frame containing coordinates for several points you can add them at once using a for loop as in the following block of code.

# %%
import folium
import pandas as pd

# Coordinates
coords = pd.DataFrame({'lon': [34.06, 34.17, 34.42],
                       'lat': [-118.25, -118.40, -118.89]})

m = folium.Map(location = [34.06, -118.25], zoom_start = 8)

# Add several markers to the map
for index, row in coords.iterrows():
  folium.Marker(location = [row["lon"], row["lat"]]).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b55ad7c8f09476b67c53cb71b7f247c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b55ad7c8f09476b67c53cb71b7f247c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b55ad7c8f09476b67c53cb71b7f247c3 = L.map(
#                 &quot;map_b55ad7c8f09476b67c53cb71b7f247c3&quot;,
#                 {
#                     center: [34.06, -118.25],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_567f315abf25eeb8d9304e68780a393e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_567f315abf25eeb8d9304e68780a393e.addTo(map_b55ad7c8f09476b67c53cb71b7f247c3);
#
#
#             var marker_99f441c59a703d082c4f8028f071ff04 = L.marker(
#                 [34.06, -118.25],
#                 {
# }
#             ).addTo(map_b55ad7c8f09476b67c53cb71b7f247c3);
#
#
#             var marker_741b71615768aadc97f420e5245cc21f = L.marker(
#                 [34.17, -118.4],
#                 {
# }
#             ).addTo(map_b55ad7c8f09476b67c53cb71b7f247c3);
#
#
#             var marker_415687909e79d48acf4bc2e311b73d62 = L.marker(
#                 [34.42, -118.89],
#                 {
# }
#             ).addTo(map_b55ad7c8f09476b67c53cb71b7f247c3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Circles
# Circles are similar to circle markers, but the difference is that the radius of circles is measured in meters while circle markers are measured in pixels. These circles can be used for instance to show an influence area of a store.

# %%
import folium

m = folium.Map(location = [34.06, -118.25], zoom_start = 8)

# Circle with a radius of 50km
folium.Circle(
    location = [34.06, -118.25],
    radius = 50000,
    color = "red",
    fill = True,
    fill_color = "blue").add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_119dca8890b95454fea43908f3a7c8ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_119dca8890b95454fea43908f3a7c8ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_119dca8890b95454fea43908f3a7c8ac = L.map(
#                 &quot;map_119dca8890b95454fea43908f3a7c8ac&quot;,
#                 {
#                     center: [34.06, -118.25],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2b542287b8266e5c64b8f6cef0e1062 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b2b542287b8266e5c64b8f6cef0e1062.addTo(map_119dca8890b95454fea43908f3a7c8ac);
#
#
#             var circle_50e36082b19456c5650c2195c2335426 = L.circle(
#                 [34.06, -118.25],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_119dca8890b95454fea43908f3a7c8ac);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Rectangles
# Similar to circles, rectangles can be added to the map, but you will need to specify the coordinates (bounds) of the rectangle, as in the example below.

# %%
import folium

m = folium.Map(location = [34.06, -118.25], zoom_start = 8)

# Rectangle coordinates
upper_left = [34.15, -118.44]
upper_right = [34.15, -118.06]
lower_right = [33.89, -118.06]
lower_left = [33.89, -118.44]

# Rectangle
folium.Rectangle(
  bounds = [upper_left, upper_right, lower_right, lower_left],
  stroke = True,
  fill = True,
  color = "blue",
  fill_color = "#3388ff",
  fill_opacity = 0.5).add_to(m)

m
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[21], line 12
#       9 lower_left = [33.89, -118.44]
#      11 # Rectangle
# ---> 12 folium.Rectangle(
#      13   bounds = [upper_left, upper_right, lower_right, lower_left],
#      14   stroke = True,
#      15   fill = True,
#      16   color = "blue",
#      17   fill_color = "#3388ff",
#      18   fill_opacity = 0.5).add_to(m)
#      20 m
#
# File ~/projects/R_themes/venv/lib/python3.13/site-packages/folium/vector_layers.py:284, in Rectangle.__init__(self, bounds, popup, tooltip, **kwargs)
#     282 self.options = path_options(line=True, radius=None, **kwargs)
#     283 self.locations = validate_locations(bounds)
# --> 284 assert len(self.locations) == 2, "Need two lat/lon pairs"
#     285 if popup is not None:
#     286     self.add_child(popup if isinstance(popup, Popup) else Popup(str(popup)))
#
# AssertionError: Need two lat/lon pairs

# %% [markdown]
# #### Polygons (GeoJSON)
# It is possible to add polygons to the folium maps with the GeoJson function. You just need to pass the geojson file to data, set a name to the layer with name and add optional styling with style_function.

# %%
import folium

m = folium.Map(location = [38.34, -0.49], zoom_start = 13)

# Geojson url
geojson_url = "https://raw.githubusercontent.com/R-CoderDotCom/data/main/sample_geojson.geojson"

# Desired styles
style = {'fillColor': 'red', 'color': 'blueviolet'}

# Geojson
folium.GeoJson(data = geojson_url, name = "geojson",
    style_function = lambda x:style).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3fb2de571fdb76515a99a048254939b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3fb2de571fdb76515a99a048254939b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3fb2de571fdb76515a99a048254939b = L.map(
#                 &quot;map_f3fb2de571fdb76515a99a048254939b&quot;,
#                 {
#                     center: [38.34, -0.49],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_affa9a311265440fa4ecdba65f54161b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_affa9a311265440fa4ecdba65f54161b.addTo(map_f3fb2de571fdb76515a99a048254939b);
#
#
#         function geo_json_ee827cc43688c951a2dd2512825be394_styler(feature) {
#             switch(feature.properties.seccion) {
#                 default:
#                     return {&quot;color&quot;: &quot;blueviolet&quot;, &quot;fillColor&quot;: &quot;red&quot;};
#             }
#         }
#
#         function geo_json_ee827cc43688c951a2dd2512825be394_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_ee827cc43688c951a2dd2512825be394 = L.geoJson(null, {
#                 onEachFeature: geo_json_ee827cc43688c951a2dd2512825be394_onEachFeature,
#
#                 style: geo_json_ee827cc43688c951a2dd2512825be394_styler,
#             ...{
# }
#         });
#
#         function geo_json_ee827cc43688c951a2dd2512825be394_add (data) {
#             geo_json_ee827cc43688c951a2dd2512825be394
#                 .addData(data);
#         }
#             geo_json_ee827cc43688c951a2dd2512825be394_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-0.4794653, 38.3443098], [-0.4783011, 38.34417519999999], [-0.4783027, 38.3441716], [-0.4783171, 38.3441453], [-0.4783221, 38.3441273], [-0.4783365, 38.3441033], [-0.4783596, 38.3440745], [-0.4783758, 38.3440438], [-0.4783761, 38.3440149], [-0.4783681, 38.3439963], [-0.4783621, 38.343984], [-0.4783639, 38.3439741], [-0.4783785, 38.3439668], [-0.4784052, 38.3439602], [-0.4784218, 38.3439557], [-0.4784348, 38.3439486], [-0.4784439, 38.3439352], [-0.4784626, 38.3439105], [-0.478481, 38.3438965], [-0.4784984, 38.343868], [-0.4785275, 38.3437745], [-0.4785115, 38.3437407], [-0.4784659, 38.3437119], [-0.4784298, 38.3437021], [-0.4783916, 38.3436915], [-0.4783635, 38.3436744], [-0.4783453, 38.3436634], [-0.4783353, 38.3436442], [-0.4783242, 38.343612], [-0.4783062, 38.3435778], [-0.4782893, 38.3435504], [-0.4782755, 38.3435329], [-0.4782605, 38.3434935], [-0.478248, 38.3434418], [-0.4782391, 38.3433857], [-0.4782294, 38.3433378], [-0.478213, 38.3432947], [-0.4781885, 38.3432374], [-0.4781847, 38.3432252], [-0.4781833, 38.3432226], [-0.478182, 38.34322], [-0.4781767, 38.3432081], [-0.4781707, 38.343196], [-0.4781599, 38.3431571], [-0.4781572, 38.3431304], [-0.4781587, 38.3431056], [-0.4781541, 38.343074], [-0.4781438, 38.3430232], [-0.4781329, 38.3429866], [-0.4781132, 38.3429344], [-0.4780913, 38.3428861], [-0.4780763, 38.3428422], [-0.4780688, 38.342815], [-0.4780671, 38.3428018], [-0.478048, 38.3427541], [-0.4780253, 38.3427082], [-0.4780127, 38.3426587], [-0.478007, 38.342619], [-0.4780073, 38.3425885], [-0.478003, 38.3425478], [-0.4779894, 38.3425047], [-0.4779806, 38.3424685], [-0.4779844, 38.3424441], [-0.4779761, 38.3424151], [-0.4779503, 38.3423767], [-0.477931, 38.3423371], [-0.4779289, 38.3423113], [-0.4779255, 38.3422874], [-0.4779139, 38.3422476], [-0.4779042, 38.3421988], [-0.4778999, 38.3421819], [-0.4779, 38.3421784], [-0.4779001, 38.3421747], [-0.4779009, 38.3421725], [-0.4779009, 38.3421702], [-0.4778973, 38.3421544], [-0.4778981, 38.3421304], [-0.4779043, 38.3420937], [-0.4779117, 38.3420668], [-0.4779161, 38.3420439], [-0.4779133, 38.3420218], [-0.4779045, 38.341987], [-0.4778976, 38.3419566], [-0.4778869, 38.3419356], [-0.4778745, 38.3419241], [-0.477861, 38.3419216], [-0.4778425, 38.3419204], [-0.4777979, 38.3419261], [-0.4777567, 38.3419388], [-0.4777083, 38.34195349999999], [-0.4776627, 38.3419691], [-0.4776174, 38.3419789], [-0.4775906, 38.3419838], [-0.4775634, 38.3419872], [-0.4775398, 38.341983], [-0.4775281, 38.3419722], [-0.4775178, 38.3419588], [-0.4775113, 38.3419425], [-0.477505, 38.3419176], [-0.4774936, 38.3418965], [-0.4774838, 38.3418909], [-0.477479, 38.3418836], [-0.4774787, 38.3418732], [-0.4774902, 38.3418505], [-0.477513, 38.3418299], [-0.4775471, 38.3418165], [-0.4776151, 38.3417919], [-0.4776731, 38.3417716], [-0.4777172, 38.341759], [-0.4777395, 38.3417568], [-0.4777691, 38.3417453], [-

# %% [markdown]
# #### Pop-ups
# Most of the functions provide an argument named popup that can be used to show a message when the layer is clicked. Try to click in the following circle marker to see the popup.

# %%
import folium

m = folium.Map(location = [34.06, -118.25], zoom_start = 8)

# Add a circle marker with a popup
folium.CircleMarker(
    location = [34.06, -118.25],
    fill = True,
    popup = "Pop up message!").add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f94ea0362524c78ad32f1db44dd86262 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f94ea0362524c78ad32f1db44dd86262&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f94ea0362524c78ad32f1db44dd86262 = L.map(
#                 &quot;map_f94ea0362524c78ad32f1db44dd86262&quot;,
#                 {
#                     center: [34.06, -118.25],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a7ec1c44c6447ef54f926c3bb303d25f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a7ec1c44c6447ef54f926c3bb303d25f.addTo(map_f94ea0362524c78ad32f1db44dd86262);
#
#
#             var circle_marker_80efa03af5af7b9dc14ec82c2f35c989 = L.circleMarker(
#                 [34.06, -118.25],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f94ea0362524c78ad32f1db44dd86262);
#
#
#         var popup_78afa2a0dd81350c91e7b39b1cda12ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d048b6786499b773d1bd9530b584d47 = $(`&lt;div id=&quot;html_0d048b6786499b773d1bd9530b584d47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pop up message!&lt;/div&gt;`)[0];
#                 popup_78afa2a0dd81350c91e7b39b1cda12ff.setContent(html_0d048b6786499b773d1bd9530b584d47);
#
#
#
#         circle_marker_80efa03af5af7b9dc14ec82c2f35c989.bindPopup(popup_78afa2a0dd81350c91e7b39b1cda12ff)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Folium plugins
# Folium provides built-in plugins with additional features. In the following subsections we will highlight some of the best plugins available, but you will find more in the original documentation.
#
# #### Mini map
# You can add a mini map to folium adding plugins.MiniMap() to the map. By default, it will display a small map at the bottom right.

# %%
import folium
from folium import plugins

m = folium.Map(location = [34.06, -118.25], zoom_start = 8)

plugins.MiniMap().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c095057d15e983403105a2af5c4f4b3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c095057d15e983403105a2af5c4f4b3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c095057d15e983403105a2af5c4f4b3d = L.map(
#                 &quot;map_c095057d15e983403105a2af5c4f4b3d&quot;,
#                 {
#                     center: [34.06, -118.25],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6beb7da6fab5cb14ef2c864f903f6b49 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6beb7da6fab5cb14ef2c864f903f6b49.addTo(map_c095057d15e983403105a2af5c4f4b3d);
#
#
#             var tile_layer_5df188c3a25510a63f4177f7aeef73a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detect_retina&quot;: false, &quot;max_native_zoom&quot;: 19, &quot;max_zoom&quot;: 19, &quot;min_zoom&quot;: 0, &quot;no_wrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_414ea65e4696e2e2742c88868404cf79 = new L.Control.MiniMap(
#                 tile_layer_5df188c3a25510a63f4177f7aeef73a4,
#                 {
#   &quot;position&quot;: &quot;bottomright&quot;,
#   &quot;width&quot;: 150,
#   &quot;height&quot;: 150,
#   &quot;collapsedWidth&quot;: 25,
#   &quot;collapsedHeight&quot;: 25,
#   &quot;zoomLevelOffset&quot;: -5,
#   &quot;centerFixed&quot;: false,
#   &quot;zoomAnimation&quot;: false,
#   &quot;toggleDisplay&quot;: false,
#   &quot;autoToggleDisplay&quot;: false,
#   &quot;minimized&quot;: false,
# }
#             );
#             map_c095057d15e983403105a2af5c4f4b3d.addControl(mini_map_414ea65e4696e2e2742c88868404cf79);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Cluster marker
# In case you have too many markers you can cluster them with MarkerCluster depending on the zoom level. You can also click over the clusters to zoom over them.

# %%
import folium
from folium import plugins
import numpy as np

# Sample longitudes and latitudes
data = np.array([np.random.uniform(low = 25, high = 50, size = 100),
                 np.random.uniform(low = -125, high = -70, size = 100)]).T

m = folium.Map([40, -100], zoom_start = 3)

plugins.MarkerCluster(data).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6eacfd82a56db8808a32bc2ef9ac1c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6eacfd82a56db8808a32bc2ef9ac1c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6eacfd82a56db8808a32bc2ef9ac1c8 = L.map(
#                 &quot;map_b6eacfd82a56db8808a32bc2ef9ac1c8&quot;,
#                 {
#                     center: [40.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5618dd8274711787154b5e34f897e817 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5618dd8274711787154b5e34f897e817.addTo(map_b6eacfd82a56db8808a32bc2ef9ac1c8);
#
#
#             var marker_cluster_94192815f66001c3fa5da4fbc1f3c6d3 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_aa0d2a0eec15934e41e9a3944dca17b4 = L.marker(
#                 [32.762541928803174, -119.9078563356423],
#                 {
# }
#             ).addTo(marker_cluster_94192815f66001c3fa5da4fbc1f3c6d3);
#
#
#             var marker_582340e40fc1b61f3972ea4228dfb823 = L.marker(
#                 [39.43975322953564, -80.36433597214855],
#                 {
# }
#             ).addTo(marker_cluster_94192815f66001c3fa5da4fbc1f3c6d3);
#
#
#             var marker_fea2e1e3d324c113c7d3f4773c80d53e = L.marker(
#                 [48.72927829734513, -88.7322991785018],
#                 {
# }
#             ).addTo(marker_cluster_94192815f66001c3fa5da4fbc1f3c6d3);
#
#
#             var marker_2886f911f480bc868fb367863a4e06dd = L.marker(
#                 [30.289715359688852, -88.94406169319778],
#                 {
# }
#             ).addTo(marker_cluster_94192815f66001c3fa5da4fbc1f3c6d3);
#
#
#             var marker_ba461f2a25b7cc80b533e5b2b829882f = L.marker(
#                 [42.9950750053133, -92.01102529907217],
#                 {
# }
#             ).addTo(marker_cluster_94192815f66001c3fa5da4fbc1f3c6d3);
#
#
#             var marker_f1eb3a845a736e3b95ab0f70ac7601f0 = L.marker(
#                 [29.516882529273083, -87.28812650922806],
#                 {
# }
#             ).addTo(marker_cluster_94192815f66001c3fa5da4fbc1f3c6d3);
#
#
#             var marker_ea5939682b9d6c386d0e372c0a8db560 = L.marker(
#                 [47.05619448478823, -94.42959447993492],
#                 {
# }
#             ).addTo(marker_cluster_94192815f66001c3fa5da4fbc1f3c6d3);
#
#
#             var marker_67471b9a48a35bb82b4564fbb1db129c = L.marker(
#                 [49.662221806377445, -106.25729530647632],
#                 {
# }
#             ).addTo(marker_cluster_94192815f66001c3fa5da4fbc1f3c6d3);
#
#
#             var marker_bca27a83d0b7fba54a25640f3bead7c0 = L.marker(
#                 [40.960484343565945, -89.89627806182084],
#                 {
# }
#             ).addTo(marker_cluster_94192815f66001c3fa5da4fbc1f3c6d3);
#
#
#             var marker_f18cd4301a06a44a572add7add247e56 = L.marker(
#                 [42.304804282461255, -121.02048855301832],
#                 {
# }
#             ).addTo(marker_cluster_94192815f66001c3fa5da4fbc1f3c6d3);
#
#
#             var marker_b72422ab03758fa348f5fef805b2c4e8 = L.marker(
#                 [36.77742336661292, -118.80399114377154],
#                 {
# }
#             ).addTo(marker_cluster_94192815f66001c3fa5da4fbc1f3c6d3);
#
#
#             var marker_1a92278fe64039ae0cf5ea04ebefece0 = L.marker(
#                 [40.21827803133432, -71.37335924076072],
#                 {
# }
#             ).addTo(marker_cluster_94192815f66001c3fa5da4fbc1f3c6d3);
#
#
#             var marker_8fd475cedfff39cbd73af37f6210ee92 = L.marker(
#                 [39.172314368376135, -109.03136547775769],
#                 {
# }
#             ).addTo(marker_cluster_94192815f66001c3fa5da4fbc1f3c6d3);
#
#
#             var marker_22580fb6bc6682540ec03323e86a475f = L.marker(
#                 [47.05114131110779, -111.70867366540729],
#                 {
# }
#             ).addTo(marker_cluster_94192815f66001c3fa5da4fbc1f3c6d3);
#
#
#             var marker_7842d0ed10353a290f34c3e5dc74c216 = L.marker(
#                 [25.63

# %% [markdown]
# #### Heat map
# Finally, if you want to create a heat map you can import HeatMap from folium.plugins with from folium.plugins import HeatMap and then use the HeatMap function in order to display your data.

# %%
import folium
from folium import plugins
from folium.plugins import HeatMap
import numpy as np

# Sample longitudes and latitudes
data = np.array([np.random.normal(35, 2, size = 100),
                 np.random.normal(-80, 2, size = 100)]).T

m = folium.Map([35, -80], zoom_start = 5)

HeatMap(data).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e915f48c762b7271e4558434ed327484 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e915f48c762b7271e4558434ed327484&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e915f48c762b7271e4558434ed327484 = L.map(
#                 &quot;map_e915f48c762b7271e4558434ed327484&quot;,
#                 {
#                     center: [35.0, -80.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_217bb2c10efb018527d6dd7fef65ee87 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_217bb2c10efb018527d6dd7fef65ee87.addTo(map_e915f48c762b7271e4558434ed327484);
#
#
#             var heat_map_e21202a0b4fcb6ddbac0bb654478a1a6 = L.heatLayer(
#                 [[34.87506223823784, -81.76434980758658], [33.26420379816819, -79.5795767224224], [34.25919710347847, -76.42205143284406], [35.176501888588895, -77.64640795555283], [33.40834465519143, -80.58404223697634], [31.777799428660874, -78.37021168308618], [35.56622014895019, -77.41366258579917], [35.273295285935745, -81.02726153856585], [32.37407449492216, -81.60214737258934], [35.31690463734159, -80.2287121301184], [36.28775649520568, -78.75550969883818], [32.646457430642904, -80.17918321507342], [36.236591935741785, -77.35386415855912], [37.53532085263536, -79.52167605984341], [34.36304627156855, -76.6785334809452], [33.105795143359465, -80.73181511985005], [34.49755226685385, -82.10010018735773], [32.963215810046336, -79.27880650240998], [36.0608872208881, -81.41265688526899], [36.37433215639265, -80.62596912850982], [33.86094513632187, -79.11795259869523], [34.94864029388486, -78.30967594249414], [33.968552216485115, -79.99443483788355], [35.85876007813325, -80.90436115699335], [37.542874177471894, -78.39700402763096], [36.38566296795482, -82.21749587904908], [35.307167094354256, -81.05922150584938], [33.58065642770029, -82.22126668766495], [37.78758338850702, -80.0016138647847], [30.24233097481848, -79.3655350355317], [35.40104915489544, -78.81914842176423], [34.277673522966, -81.61424079899224], [32.84064526842666, -80.46474405943472], [37.32472897391708, -77.79718752657432], [32.28174385258481, -79.78326658765408], [30.88531767291234, -83.18211325370683], [34.716889264499066, -80.88869378199468], [36.583429335196996, -80.13042117675285], [34.393835174329865, -81.87349159226625], [35.987185123443375, -79.11901391253474], [34.79650271644159, -76.60520765272159], [36.393134065244844, -83.02499948696293], [32.66554016819448, -80.82128097342553], [33.10195248573932, -80.92832047886563], [35.73443506999483, -80.90870924957098], [38.13592526428058, -83.12338142702629], [29.88504704679026, -81.358442490479], [32.26256883834582, -82.01279472769893], [36.967927071686596, -76.37613336777784], [33.235312398753656, -78.7383564689292], [35.737366111734865, -79.63714666842044], [33.62816788426796, -79.80139749300946], [36.27486174743795, -76.60340217092909], [35.08925633367276, -77.96376779039232], [36.29162657439635, -77.00577719765552], [38.12773589239766, -83.55593293523184], [35.642802992879346, -80.23824950295929], [34.16902925339539, -77.75475626847542], [35.91843021692013, -79.9233849926935], [33.78998220483415, -79.99686519844337], [33.95781825180383, -83.30455320668611], [40.16592718844066, -81.39201644784751], [33.978091409109574, -82.37774433173873], [36.21091291426219, -78.04976006577903], [36.38141392931819, -79.08956297747375], [38.28194184520602, -78.89002615713802], [33.27857512652683, -77.9806085641127], [33.48735561168298, -81.65613786379193], [37.154855354355725, -82.1210011261773], [33.19939470101471, -79.47255983123577], [36.24128592245942, -79.47322027855449], [33.931572587194765, -78.4063191093329], [38.088567075588195, -83.16608570269294], [32.38675145033319, -78.89693170963423], [36.574885275612665, -80.3931708558541], [38.076242703979965, -84.23315808758159], [36.680779969580826, -80.99506857254775], [34.5456863067445, -78.62985305806865], [36.44727205764241, -80.77014618794944], [34.04842808466611, -80.6076289630016], [39.17087172469647, -80.54975784196886], [35.81983223309364, -77.68485426436565], [34.402911231869, -79.17458300048764], [32.143507942884604, -77.19264329804544], [32.104195880705305, -83.2322973143363], [34.42193359972198, -79.16419859473199], [34.19471917305993, -82.59198723403051], [33.6694589768721, -82.0195772641021], [35.49035083399238, -77.7312236582159
