# %% [markdown]
# Perfect 🚀 Let’s set up a Jupyter Notebook where you can use Python for data wrangling and Observable Plot / D3.js for visualization.
#
# Since Plot and D3 are JavaScript libraries, we’ll bridge them into Jupyter with IPython.display and a little HTML injection.
#
# Import display tools in Python

# %%
from IPython.display import HTML, display
import pandas as pd

# %%
# Create some Python data

# Example dataset
df = pd.DataFrame({
    "x": [1, 2, 3, 4, 5],
    "y": [3, 7, 4, 9, 6]
})

df
# Out:
#    x  y
# 0  1  3
# 1  2  7
# 2  3  4
# 3  4  9
# 4  5  6

# %% [markdown]
# ### Render with Observable Plot
#
# We pass the dataframe into JavaScript using .to_json(orient="records").

# %%
data_json = df.to_json(orient="records")

html_code = f"""
<div id="chart"></div>

<script src="https://cdn.jsdelivr.net/npm/d3@7"></script>
<script src="https://cdn.jsdelivr.net/npm/@observablehq/plot"></script>

<script>
  const data = {data_json};

  const chart = Plot.plot({{
    marks: [
      Plot.line(data, {{x: "x", y: "y"}}),
      Plot.dot(data, {{x: "x", y: "y"}})
    ],
    width: 500,
    height: 300
  }});

  document.getElementById("chart").appendChild(chart);
</script>
"""

display(HTML(html_code))
# Out:
# <div id="chart"></div>
#
# <script src="https://cdn.jsdelivr.net/npm/d3@7"></script>
# <script src="https://cdn.jsdelivr.net/npm/@observablehq/plot"></script>
#
# <script>
#   const data = [{"x":1,"y":3},{"x":2,"y":7},{"x":3,"y":4},{"x":4,"y":9},{"x":5,"y":6}];
#
#   const chart = Plot.plot({
#     marks: [
#       Plot.line(data, {x: "x", y: "y"}),
#       Plot.dot(data, {x: "x", y: "y"})
#     ],
#     width: 500,
#     height: 300
#   });
#
#   document.getElementById("chart").appendChild(chart);
# </script>

# %% [markdown]
# 👉 This will render an interactive Observable Plot chart inside your notebook, based on the Pandas dataframe.
#
# ✅ (Optional): Wrap into a helper function
#
# To make life easier:

# %%
def plot_with_observable(df, x, y, kind="line"):
    data_json = df.to_json(orient="records")
    mark = f"Plot.{kind}(data, {{x: '{x}', y: '{y}'}})"
    
    html_code = f"""
    <div id="chart"></div>
    <script src="https://cdn.jsdelivr.net/npm/d3@7"></script>
    <script src="https://cdn.jsdelivr.net/npm/@observablehq/plot"></script>
    <script>
      const data = {data_json};
      const chart = Plot.plot({{
        marks: [{mark}],
        width: 500,
        height: 300
      }});
      document.getElementById("chart").appendChild(chart);
    </script>
    """
    display(HTML(html_code))

# Example
plot_with_observable(df, "x", "y", kind="line")
# Out:
#     <div id="chart"></div>
#     <script src="https://cdn.jsdelivr.net/npm/d3@7"></script>
#     <script src="https://cdn.jsdelivr.net/npm/@observablehq/plot"></script>
#     <script>
#       const data = [{"x":1,"y":3},{"x":2,"y":7},{"x":3,"y":4},{"x":4,"y":9},{"x":5,"y":6}];
#       const chart = Plot.plot({
#         marks: [Plot.line(data, {x: 'x', y: 'y'})],
#         width: 500,
#         height: 300
#       });
#       document.getElementById("chart").appendChild(chart);
#     </script>

# %% [markdown]
# ### Extend the helper function
#
# We’ll add an option to write the chart into an HTML file.

# %%
from IPython.display import HTML, display

def plot_with_observable(df, x, y, kind="line", filename=None):
    data_json = df.to_json(orient="records")
    mark = f"Plot.{kind}(data, {{x: '{x}', y: '{y}'}})"
    
    html_code = f"""
    <!DOCTYPE html>
    <html>
    <head>
      <meta charset="utf-8">
      <title>Observable Plot Export</title>
      <script src="https://cdn.jsdelivr.net/npm/d3@7"></script>
      <script src="https://cdn.jsdelivr.net/npm/@observablehq/plot"></script>
    </head>
    <body>
      <div id="chart"></div>
      <script>
        const data = {data_json};
        const chart = Plot.plot({{
          marks: [{mark}],
          width: 600,
          height: 400
        }});
        document.getElementById("chart").appendChild(chart);
      </script>
    </body>
    </html>
    """
    
    # Display inside Jupyter
    if filename is None:
        display(HTML(html_code))
    else:
        with open(filename, "w", encoding="utf-8") as f:
            f.write(html_code)
        print(f"✅ Exported to {filename}")

# %% [markdown]
# ### Use it in Jupyter

# %%
import pandas as pd

# Example data
df = pd.DataFrame({
    "x": [1, 2, 3, 4, 5],
    "y": [3, 7, 4, 9, 6]
})

# Show in Jupyter
plot_with_observable(df, "x", "y", kind="line")

# Export to HTML
plot_with_observable(df, "x", "y", kind="line", filename="my_chart.html")
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#       <meta charset="utf-8">
#       <title>Observable Plot Export</title>
#       <script src="https://cdn.jsdelivr.net/npm/d3@7"></script>
#       <script src="https://cdn.jsdelivr.net/npm/@observablehq/plot"></script>
#     </head>
#     <body>
#       <div id="chart"></div>
#       <script>
#         const data = [{"x":1,"y":3},{"x":2,"y":7},{"x":3,"y":4},{"x":4,"y":9},{"x":5,"y":6}];
#         const chart = Plot.plot({
#           marks: [Plot.line(data, {x: 'x', y: 'y'})],
#           width: 600,
#           height: 400
#         });
#         document.getElementById("chart").appendChild(chart);
#       </script>
#     </body>
#     </html>
# ✅ Exported to my_chart.html

# %% [markdown]
# ### Isotype Chart
# Emoji icons repeated as many times as necessary, and rendered with the text mark for unit charts à la Isotype.

# %%
from IPython.display import HTML

html_code = """
<div id="chart"></div>

<script src="https://cdn.jsdelivr.net/npm/d3@7"></script>
<script src="https://cdn.jsdelivr.net/npm/@observablehq/plot"></script>

<script>
const emoji = { cattle: "🐄", sheep: "🐑", pigs: "🐖" };

// This dataset is purely made up.
const data = [
  { animal: "pigs", country: "Great Britain", count: 1354979 },
  { animal: "cattle", country: "Great Britain", count: 3962921 },
  { animal: "sheep", country: "Great Britain", count: 10931215 },
  { animal: "pigs", country: "United States", count: 6281935 },
  { animal: "cattle", country: "United States", count: 9917873 },
  { animal: "sheep", country: "United States", count: 7084151 }
];

const chart = Plot.plot({
  width: 610,
  height: 380,
  marginLeft: 60,
  marginRight: 100,
  marginTop: 30,
  y: {label: null},
  fy: {paddingInner: 0.27, label: null},
  marks: [
    Plot.text(data, {
      frameAnchor: "left",
      fontSize: 40,
      text: (d) => `${emoji[d.animal]} `.repeat(Math.round(d.count / 1e6)),
      dx: 20,
      y: "animal",
      fy: "country"
    }),
    Plot.axisFy({ fontSize: 18, frameAnchor: "top", dy: -18 })
  ],
  caption: "Livestock (millions)"
});

document.getElementById("chart").appendChild(chart);
</script>
"""

HTML(html_code)
# Out:
# <div id="chart"></div>
#
# <script src="https://cdn.jsdelivr.net/npm/d3@7"></script>
# <script src="https://cdn.jsdelivr.net/npm/@observablehq/plot"></script>
#
# <script>
# const emoji = { cattle: "🐄", sheep: "🐑", pigs: "🐖" };
#
# // This dataset is purely made up.
# const data = [
#   { animal: "pigs", country: "Great Britain", count: 1354979 },
#   { animal: "cattle", country: "Great Britain", count: 3962921 },
#   { animal: "sheep", country: "Great Britain", count: 10931215 },
#   { animal: "pigs", country: "United States", count: 6281935 },
#   { animal: "cattle", country: "United States", count: 9917873 },
#   { animal: "sheep", country: "United States", count: 7084151 }
# ];
#
# const chart = Plot.plot({
#   width: 610,
#   height: 380,
#   marginLeft: 60,
#   marginRight: 100,
#   marginTop: 30,
#   y: {label: null},
#   fy: {paddingInner: 0.27, label: null},
#   marks: [
#     Plot.text(data, {
#       frameAnchor: "left",
#       fontSize: 40,
# ...

# %%
with open("livestock_chart.html", "w", encoding="utf-8") as f:
    f.write(html_code)

print("✅ Exported to livestock_chart.html")
# Out:
# ✅ Exported to livestock_chart.html

# %%
import pandas as pd
from IPython.display import HTML

# Example dataset
df = pd.DataFrame([
    {"animal": "pigs", "country": "Great Britain", "count": 1354979},
    {"animal": "cattle", "country": "Great Britain", "count": 3962921},
    {"animal": "sheep", "country": "Great Britain", "count": 10931215},
    {"animal": "pigs", "country": "United States", "count": 6281935},
    {"animal": "cattle", "country": "United States", "count": 9917873},
    {"animal": "sheep", "country": "United States", "count": 7084151}
])

# Convert DataFrame to JSON format usable in JS
data_json = df.to_json(orient="records")

html_code = f"""
<div id="chart"></div>

<script src="https://cdn.jsdelivr.net/npm/d3@7"></script>
<script src="https://cdn.jsdelivr.net/npm/@observablehq/plot"></script>

<script>
const emoji = {{ cattle: "🐄", sheep: "🐑", pigs: "🐖" }};
const data = {data_json};

const chart = Plot.plot({{
  width: 610,
  height: 380,
  marginLeft: 60,
  marginRight: 100,
  marginTop: 30,
  y: {{label: null}},
  fy: {{paddingInner: 0.27, label: null}},
  marks: [
    Plot.text(data, {{
      frameAnchor: "left",
      fontSize: 40,
      text: (d) => `${{emoji[d.animal]}} `.repeat(Math.round(d.count / 1e6)),
      dx: 20,
      y: "animal",
      fy: "country"
    }}),
    Plot.axisFy({{ fontSize: 18, frameAnchor: "top", dy: -18 }})
  ],
  caption: "Livestock (millions)"
}});

document.getElementById("chart").appendChild(chart);
</script>
"""

HTML(html_code)
# Out:
# <div id="chart"></div>
#
# <script src="https://cdn.jsdelivr.net/npm/d3@7"></script>
# <script src="https://cdn.jsdelivr.net/npm/@observablehq/plot"></script>
#
# <script>
# const emoji = { cattle: "🐄", sheep: "🐑", pigs: "🐖" };
# const data = [{"animal":"pigs","country":"Great Britain","count":1354979},{"animal":"cattle","country":"Great Britain","count":3962921},{"animal":"sheep","country":"Great Britain","count":10931215},{"animal":"pigs","country":"United States","count":6281935},{"animal":"cattle","country":"United States","count":9917873},{"animal":"sheep","country":"United States","count":7084151}];
#
# const chart = Plot.plot({
#   width: 610,
#   height: 380,
#   marginLeft: 60,
#   marginRight: 100,
#   marginTop: 30,
#   y: {label: null},
#   fy: {paddingInner: 0.27, label: null},
#   marks: [
#     Plot.text(data, {
#       frameAnchor: "left",
#       fontSize: 40,
#       text: (d) => `${emoji[d.animal]} `.repeat(Math.round(d.count / 1e6)),
#       dx: 20,
# ...

# %%
with open("livestock_chart1.html", "w", encoding="utf-8") as f:
    f.write(html_code)

print("✅ Exported to livestock_chart1.html")
# Out:
# ✅ Exported to livestock_chart1.html
